# %% [markdown]
# ## demo for parsing

# %%
# %load_ext autoreload
# %autoreload 2
from tree_sitter_languages import get_parser
from tree_sitter import Language, Parser
JAVA_LANGUAGE = Language('build/my-languages.so', 'java')
parser = Parser()

with open("grammar_test.java", "r") as file:
    source_code = file.read()
print(source_code)

import utils
tree = parser.parse(bytes(source_code, "utf8"))
print(utils.format_code(tree.root_node.sexp()))
# Out:
# //4sum
# class Solution {
#     String s = "hello".substring(0, 2);
#     char c = 'c';
#     int a = 0xAAAAAAAA;
#     long l = 1L;
# }
# (program
#     (line_comment)
#     (class_declaration
#         name: (identifier)
#         body: (class_body
#             (field_declaration
#                 type: (type_identifier)
#                 declarator: (variable_declarator
#                     name: (identifier)
#                     value: (method_invocation
#                         object: (string_literal
#                             (string_fragment)
#                         )
#                         name: (identifier)
#                         arguments: (argument_list
#                             (decimal_integer_literal)
#                             (decimal_integer_literal)
#                         )
#                     )
#                 )
#             )
#             (field_declaration
#                 type: (integral_type)
#                 declarator: (variable_declarator
#                     name: (identifier)
#                     value: (character_literal)
#                 )
#             )
#             (field_declaration
#                 type: (integral_type)
#                 declarator: (variable_declarator
#                     name: (identifier)
#                     value: (hex_integer_literal)
#                 )
#             )
#             (field_declaration
#                 type: (integral_type)
#                 declarator: (variable_declarator
#                     name: (identifier)
#                     value: (decimal_integer_literal)
#                 )
#             )
#         )
#     )
# )

# %% [markdown]
# ## Parse all solutions

# %%
# get program model from a java file
def getProgram(file_path):
    with open(file_path, "r") as file:
        source_code = file.read()
        utils.source_code_line = source_code.split("\n")
    tree = parser.parse(bytes(source_code, "utf8"))
    return utils.visit_program(tree.root_node)

# print program as a java file
def printJava(program):
    return utils.addIndentation(program.toString())

# validate the parser and the java generation
def validateJava(file_path):
    return_value = True
    try:
        program = getProgram(file_path)
        javaCode= printJava(program)
        tree = parser.parse(bytes(javaCode, "utf8"))
    except Exception as e:
        print(f"\nError in parsing {file_path}")
        print(e)
        return_value = False
    finally:
        return return_value
    
test_filepath = "grammar_test.java"
program = getProgram(test_filepath)
with open("test.java", "w") as file:
    file.write(printJava(program))
validateJava("test.java")
# Out:
# True

# %%
import os
import subprocess
# Path to the solutions folder
folder_path = "solutions"

# Get the list of Java code files in the folder
java_files = [file for file in os.listdir(folder_path) if file.endswith(".java")]

java_files.sort()
error_cnt=0
# Loop through each Java code file
for file_name in java_files[:]:
    file_path = os.path.join(folder_path, file_name)
    
    # using the parser to validate the java file
    if not validateJava(file_path):
        error_cnt+=1

    # using javac to validate the java file
    # try:
    #     with open("test.java", "w") as file:
    #         file.write(printJava(getProgram(file_path)))
    # except Exception as e:
    #     print(f"\nError in parsing {file_path}")
    #     print(e)
    #     error_cnt+=1
    #     continue
    # res = subprocess.run(
    #             ["javac", "-d", "tmp", file_path],
    #             stdout=subprocess.PIPE,
    #             stderr=subprocess.PIPE,
    #             timeout=60,
    #         )
    # if res.returncode != 0:
    #     print(f"\nError in parsing {file_path}")
    #     print(res.stderr.decode("utf-8"))
    #     error_cnt+=1
print(f"Total errors: {error_cnt} out of {len(java_files)} files.")
# Out:
# Error in parsing solutions/all-nodes-distance-k-in-binary-tree_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<>()
#
# Error in parsing solutions/all-paths-from-source-lead-to-destination_0.java
# classcomponent中有未知类型enum_declaration enum Color { GRAY, BLACK }
#
# Error in parsing solutions/array-partition_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/array-partition_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/as-far-from-land-as-possible_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/basic-calculator_0.java
# expression中有未知类型:instanceof_expression stack.peek() instanceof Integer
#
# Error in parsing solutions/best-team-with-no-conflicts_0.java
# expression中有未知类型:lambda_expression (a,b) -> a[0] == b[0] ? a[1]-b[1] : a[0]-b[0]
#
# Error in parsing solutions/best-team-with-no-conflicts_1.java
# expression中有未知类型:lambda_expression (a,b) -> a[0] == b[0] ? a[1]-b[1] : a[0]-b[0]
#
# Error in parsing solutions/best-team-with-no-conflicts_2.java
# expression中有未知类型:lambda_expression (a,b) -> a[0] == b[0] ? a[1]-b[1] : a[0]-b[0]
#
# Error in parsing solutions/binary-tree-vertical-order-traversal_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/buy-two-chocolates_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/campus-bikes-ii_3.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/campus-bikes_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/candy-crush_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/cheapest-flights-within-k-stops_0.java
# expression中有未知类型:lambda_expression value -> new ArrayList<>()
#
# Error in parsing solutions/cheapest-flights-within-k-stops_2.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/closest-binary-search-tree-value-ii_1.java
# expression中有未知类型:lambda_expression (a, b) -> Math.abs(a - target) > Math.abs(b - target) ? -1: 1
#
# Error in parsing solutions/closest-leaf-in-a-binary-tree_0.java
# statement中有未知类型throw_statement throw null;
#
# Error in parsing solutions/combination-sum-ii_0.java
# expression中有未知类型:lambda_expression (key, value) -> {
#             counterList.add(new int[]{key, value});
#         }
#
# Error in parsing solutions/compare-version-numbers_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/confusing-number-ii_0.java
# statement中有未知类型switch_expression switch(c) {
#             case '0':case '1':case'8': return c;
#             case '6': return '9';
#             case '9': return '6';
#             default: return '?';
#         }
#
# Error in parsing solutions/connecting-cities-with-minimum-cost_3.java
# expression中有未知类型:lambda_expression (a, b) -> a[2] - b[2]
#
# Error in parsing solutions/constrained-subsequence-sum_0.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             return b[0] - a[0];
#         }
#
# Error in parsing solutions/construct-binary-tree-from-string_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/construct-binary-tree-from-string_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/count-nice-pairs-in-an-array_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/count-nodes-equal-to-average-of-subtree_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/count-univalue-subtrees_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/count-unreachable-pairs-of-nodes-in-an-undirected-graph_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<Integer>()
#
# Error in parsing solutions/count-unreachable-pairs-of-nodes-in-an-undirected-graph_1.java
# expression中有未知类型:lambda_expression k -> new ArrayList<Integer>()
#
# Error in parsing solutions/course-schedule-iii_0.java
# expression中有未知类型:lambda_expression (a, b) -> a[1] - b[1]
#
# Error in parsing solutions/course-schedule-iii_1.java
# expression中有未知类型:lambda_expression (a, b) -> a[1] - b[1]
#
# Error in parsing solutions/course-schedule-iii_2.java
# expression中有未知类型:lambda_expression (a, b) -> a[1] - b[1]
#
# Error in parsing solutions/course-schedule-iii_3.java
# expression中有未知类型:lambda_expression (a, b) -> a[1] - b[1]
#
# Error in parsing solutions/course-schedule-iii_4.java
# expression中有未知类型:lambda_expression (a, b) -> b - a
#
# Error in parsing solutions/create-sorted-array-through-instructions_2.java
# arraycreationexpression中有未知类型dimensions []
#
# Error in parsing solutions/critical-connections-in-a-network_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/decoded-string-at-index_0.java
# statement中有未知类型throw_statement throw null;
#
# Error in parsing solutions/deepest-leaves-sum_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/deepest-leaves-sum_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/delete-columns-to-make-sorted-iii_0.java
# statement中有未知类型labeled_statement search: for (int j = i+1; j < W; ++j) {
#                 for (String row: A)
#                     if (row.charAt(i) > row.charAt(j))
#                         continue search;
#
#                 dp[i] = Math.max(dp[i], 1 + dp[j]);
#             }
#
# Error in parsing solutions/design-compressed-string-iterator_1.java
# expression中有未知类型:method_reference Integer::parseInt
#
# Error in parsing solutions/design-excel-sum-formula_0.java
# classcomponent中有未知类型class_declaration class Formula {
#         Formula(HashMap < String, Integer > c, int v) {
#             val = v;
#             cells = c;
#         }
#         HashMap < String, Integer > cells;
#         int val;
#     }
#
# Error in parsing solutions/design-file-system_1.java
# classcomponent中有未知类型class_declaration class TrieNode {
#
#         String name;
#         int val = -1;
#         Map<String, TrieNode> map = new HashMap<>();
#
#         TrieNode (String name) {
#             this.name = name;
#         }
#     }
#
# Error in parsing solutions/design-graph-with-shortest-path-calculator_1.java
# expression中有未知类型:lambda_expression row -> Arrays.fill(row, (int)1e9)
#
# Error in parsing solutions/design-hashmap_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/design-hit-counter_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/design-in-memory-file-system_0.java
# classcomponent中有未知类型class_declaration class Dir {
#         HashMap < String, Dir > dirs = new HashMap < > ();
#         HashMap < String, String > files = new HashMap < > ();
#     }
#
# Error in parsing solutions/design-in-memory-file-system_1.java
# classcomponent中有未知类型class_declaration class File {
#         boolean isfile = false;
#         HashMap < String, File > files = new HashMap < > ();
#         String content = "";
#     }
#
# Error in parsing solutions/design-log-storage-system_0.java
# expression中有未知类型:method_reference Integer::parseInt
#
# Error in parsing solutions/design-search-autocomplete-system_3.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             int hotA = currNode.sentences.get(a);
#             int hotB = currNode.sentences.get(b);
#             if (hotA == hotB) {
#                 return a.compareTo(b);
#             }
#
#             return hotB - hotA;
#         }
#
# Error in parsing solutions/design-search-autocomplete-system_4.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             int hotA = currNode.sentences.get(a);
#             int hotB = currNode.sentences.get(b);
#             if (hotA == hotB) {
#                 return b.compareTo(a);
#             }
#
#             return hotA - hotB;
#         }
#
# Error in parsing solutions/design-snake-game_0.java
# statement中有未知类型switch_expression switch (direction) {
#     case "U":
#         newHeadRow--;
#         break;
#     case "D":
#         newHeadRow++;
#         break;
#     case "L":
#         newHeadColumn--;
#         break;
#     case "R":
#         newHeadColumn++;
#         break;
#     }
#
# Error in parsing solutions/design-underground-system_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/detonate-the-maximum-bombs_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<>()
#
# Error in parsing solutions/detonate-the-maximum-bombs_1.java
# expression中有未知类型:lambda_expression k -> new ArrayList<>()
#
# Error in parsing solutions/detonate-the-maximum-bombs_2.java
# expression中有未知类型:lambda_expression k -> new ArrayList<>()
#
# Error in parsing solutions/diagonal-traverse-ii_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/distinct-subsequences_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/domino-and-tromino-tiling_3.java
# arrayinitializer中有未知类型line_comment // Initialize the square matrix.
#
# Error in parsing solutions/domino-and-tromino-tiling_4.java
# arrayinitializer中有未知类型line_comment // Initialize the square matrix
#
# Error in parsing solutions/encode-and-decode-strings_0.java
# invalid literal for int() with base 10: ';'
#
# Error in parsing solutions/equal-row-and-column-pairs_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/equal-row-and-column-pairs_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/equal-row-and-column-pairs_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/erect-the-fence_0.java
# arraycreationexpression中有未知类型dimensions []
#
# Error in parsing solutions/evaluate-division_0.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/evaluate-division_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/evaluate-reverse-polish-notation_1.java
# statement中有未知类型switch_expression switch (tokens[currentPosition]) {
#                 case "+":
#                     newValue = number1 + number2;
#                     break;
#                 case "-":
#                     newValue = number1 - number2;
#                     break;
#                 case "*":
#                     newValue = number1 * number2;
#                     break;
#                 case "/":
#                     newValue = number1 / number2;
#                     break;
#             }
#
# Error in parsing solutions/evaluate-reverse-polish-notation_3.java
# statement中有未知类型switch_expression switch (token) {
#                 case "+":
#                     result = number1 + number2;
#                     break;
#                 case "-":
#                     result = number1 - number2;
#                     break;
#                 case "*":
#                     result = number1 * number2;
#                     break;
#                 case "/":
#                     result = number1 / number2;
#                     break;
#             }
#
# Error in parsing solutions/expression-add-operators_0.java
# expression中有未知类型:lambda_expression v -> sb.append(v)
#
# Error in parsing solutions/fair-candy-swap_0.java
# statement中有未知类型throw_statement throw null;
#
# Error in parsing solutions/find-if-path-exists-in-graph_0.java
# expression中有未知类型:lambda_expression val -> new ArrayList<Integer>()
#
# Error in parsing solutions/find-if-path-exists-in-graph_1.java
# expression中有未知类型:lambda_expression val -> new ArrayList<Integer>()
#
# Error in parsing solutions/find-if-path-exists-in-graph_2.java
# expression中有未知类型:lambda_expression val -> new ArrayList<Integer>()
#
# Error in parsing solutions/find-k-closest-elements_0.java
# expression中有未知类型:lambda_expression (num1, num2) -> Math.abs(num1 - x) - Math.abs(num2 - x)
#
# Error in parsing solutions/find-k-th-smallest-pair-distance_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/find-k-th-smallest-pair-distance_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/find-largest-value-in-each-tree-row_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/find-lucky-integer-in-an-array_2.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/find-original-array-from-doubled-array_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/find-original-array-from-doubled-array_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/find-right-interval_1.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/find-right-interval_2.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/find-right-interval_4.java
# expression中有未知类型:lambda_expression (a, b) -> a[1] - b[1]
#
# Error in parsing solutions/find-the-difference_1.java
# localvariabledeclaration中内部有未知子节点variable_declarator
#
# Error in parsing solutions/find-the-index-of-the-first-occurrence-in-a-string_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/flatten-2d-vector_0.java
# statement中有未知类型throw_statement throw new NoSuchElementException();
#
# Error in parsing solutions/flatten-2d-vector_1.java
# statement中有未知类型throw_statement throw new NoSuchElementException();
#
# Error in parsing solutions/flatten-binary-tree-to-linked-list_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/furthest-building-you-can-reach_0.java
# expression中有未知类型:lambda_expression (a, b) -> a - b
#
# Error in parsing solutions/furthest-building-you-can-reach_1.java
# expression中有未知类型:lambda_expression (a, b) -> b - a
#
# Error in parsing solutions/furthest-building-you-can-reach_3.java
# expression中有未知类型:lambda_expression (a,b) -> a[0] - b[0]
#
# Error in parsing solutions/greatest-common-divisor-of-strings_1.java
# primaryexpression中有未知类型:parenthesized_expression (str1 + str2)
#
# Error in parsing solutions/image-overlap_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/index-pairs-of-a-string_1.java
# arraycreationexpression中有未知类型dimensions []
#
# Error in parsing solutions/integer-to-english-words_0.java
# statement中有未知类型switch_expression switch(num) {
#       case 2: return "Twenty";
#       case 3: return "Thirty";
#       case 4: return "Forty";
#       case 5: return "Fifty";
#       case 6: return "Sixty";
#       case 7: return "Seventy";
#       case 8: return "Eighty";
#       case 9: return "Ninety";
#     }
#
# Error in parsing solutions/interval-list-intersections_0.java
# arraycreationexpression中有未知类型dimensions []
#
# Error in parsing solutions/jump-game-iv_0.java
# expression中有未知类型:lambda_expression v -> new LinkedList<>()
#
# Error in parsing solutions/jump-game-iv_1.java
# expression中有未知类型:lambda_expression v -> new LinkedList<>()
#
# Error in parsing solutions/jump-game-vi_1.java
# expression中有未知类型:lambda_expression (a, b) -> b[0] - a[0]
#
# Error in parsing solutions/jump-game-vi_4.java
# expression中有未知类型:lambda_expression (a, b) -> b[0] - a[0]
#
# Error in parsing solutions/jump-game_2.java
# program中有未知类型enum_declaration enum Index {
#     GOOD, BAD, UNKNOWN
# }
#
# Error in parsing solutions/jump-game_3.java
# program中有未知类型enum_declaration enum Index {
#     GOOD, BAD, UNKNOWN
# }
#
# Error in parsing solutions/k-diff-pairs-in-an-array_2.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/k-inverse-pairs-array_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/k-inverse-pairs-array_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/k-inverse-pairs-array_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/k-inverse-pairs-array_3.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/k-inverse-pairs-array_4.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/k-inverse-pairs-array_5.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/k-th-smallest-prime-fraction_1.java
# expression中有未知类型:lambda_expression (a, b) ->
#                 A[a[0]] * A[b[1]] - A[a[1]] * A[b[0]]
#
# Error in parsing solutions/kill-process_1.java
# classcomponent中有未知类型class_declaration class Node {
#         int val;
#         List < Node > children = new ArrayList < > ();
#     }
#
# Error in parsing solutions/kth-smallest-element-in-a-sorted-matrix_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/largest-3-same-digit-number-in-string_1.java
# statement中有未知类型ERROR return maxDigit == '' ? "" : new String(new char[]{maxDigit, maxDigit, maxDigit});
#
# Error in parsing solutions/largest-color-value-in-a-directed-graph_0.java
# expression中有未知类型:lambda_expression k->new ArrayList<Integer>()
#
# Error in parsing solutions/largest-color-value-in-a-directed-graph_1.java
# expression中有未知类型:lambda_expression k->new ArrayList<Integer>()
#
# Error in parsing solutions/largest-component-size-by-common-factor_1.java
# expression中有未知类型:lambda_expression (x, y) -> x > y ? x : y
#
# Error in parsing solutions/largest-component-size-by-common-factor_3.java
# expression中有未知类型:lambda_expression (x, y) -> x > y ? x : y
#
# Error in parsing solutions/largest-submatrix-with-rearrangements_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/largest-unique-number_1.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/logger-rate-limiter_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/longest-palindrome-by-concatenating-two-letter-words_0.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/longest-path-with-different-adjacent-characters_0.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/longest-string-chain_1.java
# expression中有未知类型:lambda_expression (a, b) -> a.length() - b.length()
#
# Error in parsing solutions/lowest-common-ancestor-of-a-binary-tree_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/magic-squares-in-grid_0.java
# formalparameters中有未知类型spread_parameter int... vals
#
# Error in parsing solutions/majority-element_1.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/make-array-strictly-increasing_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/max-points-on-a-line_0.java
# expression中有未知类型:method_reference Integer::sum
#
# Error in parsing solutions/max-stack_1.java
# expression中有未知类型:lambda_expression (a, b) -> b[0] - a[0] == 0 ? b[1] - a[1] : b[0] - a[0]
#
# Error in parsing solutions/maximal-network-rank_0.java
# expression中有未知类型:lambda_expression k -> new HashSet<>()
#
# Error in parsing solutions/maximize-score-after-n-operations_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/maximum-average-subtree_0.java
# expression中有未知类型:line_comment // max average from child nodes
#
# Error in parsing solutions/maximum-frequency-stack_0.java
# expression中有未知类型:lambda_expression z-> new Stack()
#
# Error in parsing solutions/maximum-length-of-pair-chain_0.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/maximum-length-of-pair-chain_1.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/maximum-length-of-pair-chain_2.java
# expression中有未知类型:lambda_expression (a, b) -> a[1] - b[1]
#
# Error in parsing solutions/maximum-number-of-events-that-can-be-attended-ii_0.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/maximum-number-of-events-that-can-be-attended-ii_1.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/maximum-number-of-events-that-can-be-attended-ii_2.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/maximum-number-of-events-that-can-be-attended-ii_3.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/maximum-number-of-events-that-can-be-attended-ii_4.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/maximum-number-of-points-with-cost_0.java
# expression中有未知类型:lambda_expression x -> x
#
# Error in parsing solutions/maximum-subsequence-score_0.java
# expression中有未知类型:lambda_expression (a, b) -> a - b
#
# Error in parsing solutions/maximum-units-on-a-truck_1.java
# expression中有未知类型:lambda_expression (a, b) -> b[1] - a[1]
#
# Error in parsing solutions/maximum-units-on-a-truck_2.java
# expression中有未知类型:lambda_expression (a, b)->b[1] - a[1]
#
# Error in parsing solutions/maximum-xor-of-two-numbers-in-an-array_3.java
# primaryexpression中有未知类型:parenthesized_expression (Integer.toBinaryString(maxNum))
#
# Error in parsing solutions/meeting-rooms_2.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a[0], b[0])
#
# Error in parsing solutions/meeting-scheduler_0.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/meeting-scheduler_1.java
# expression中有未知类型:lambda_expression (slot1, slot2) -> slot1[0] - slot2[0]
#
# Error in parsing solutions/merge-intervals_0.java
# arraycreationexpression中有未知类型dimensions []
#
# Error in parsing solutions/merge-intervals_1.java
# arraycreationexpression中有未知类型dimensions []
#
# Error in parsing solutions/min-cost-to-connect-all-points_0.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a[0], b[0])
#
# Error in parsing solutions/min-cost-to-connect-all-points_1.java
# expression中有未知类型:lambda_expression (a, b) -> (a.getKey() - b.getKey())
#
# Error in parsing solutions/minimize-max-distance-to-gas-station_2.java
# expression中有未知类型:lambda_expression (a, b) ->
#             (double)b[0]/b[1] < (double)a[0]/a[1] ? -1 : 1
#
# Error in parsing solutions/minimize-maximum-pair-sum-in-array_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/minimize-the-maximum-difference-of-pairs_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/minimum-absolute-difference_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/minimum-absolute-difference_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/minimum-absolute-difference_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/minimum-ascii-delete-sum-for-two-strings_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/minimum-cost-to-make-array-equal_0.java
# expression中有未知类型:lambda_expression (a, b) -> a[0] - b[0]
#
# Error in parsing solutions/minimum-fuel-cost-to-report-to-the-capital_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<Integer>()
#
# Error in parsing solutions/minimum-fuel-cost-to-report-to-the-capital_1.java
# expression中有未知类型:lambda_expression k -> new ArrayList<Integer>()
#
# Error in parsing solutions/minimum-number-of-arrows-to-burst-balloons_0.java
# expression中有未知类型:lambda_expression (o1, o2) -> {
#             // We can't simply use the o1[1] - o2[1] trick, as this will cause an
#             // integer overflow for very large or small values.
#             if (o1[1] == o2[1]) return 0;
#             if (o1[1] < o2[1]) return -1;
#             return 1;
#         }
#
# Error in parsing solutions/minimum-number-of-flips-to-convert-binary-matrix-to-zero-matrix_0.java
# expression中有未知类型:method_reference Integer::intValue
#
# Error in parsing solutions/minimum-score-of-a-path-between-two-cities_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<List<Integer>>()
#
# Error in parsing solutions/minimum-score-of-a-path-between-two-cities_1.java
# expression中有未知类型:lambda_expression k -> new ArrayList<List<Integer>>()
#
# Error in parsing solutions/minimum-time-to-collect-all-apples-in-a-tree_0.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/minimum-window-substring_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/most-frequent-subtree-sum_0.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/most-frequent-subtree-sum_1.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/most-profit-assigning-work_0.java
# expression中有未知类型:lambda_expression (a, b) -> a.x - b.x
#
# Error in parsing solutions/n-repeated-element-in-size-2n-array_0.java
# statement中有未知类型throw_statement throw null;
#
# Error in parsing solutions/n-repeated-element-in-size-2n-array_1.java
# statement中有未知类型throw_statement throw null;
#
# Error in parsing solutions/network-delay-time_0.java
# expression中有未知类型:lambda_expression (a, b) -> a.getKey() - b.getKey()
#
# Error in parsing solutions/network-delay-time_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/next-greater-element-iii_1.java
# statement中有未知类型try_statement try {
#             return Integer.parseInt(new String(a));
#         } catch (Exception e) {
#             return -1;
#         }
#
# Error in parsing solutions/number-of-distinct-islands_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/number-of-good-pairs_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/number-of-good-pairs_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/number-of-increasing-paths-in-a-grid_0.java
# expression中有未知类型:lambda_expression (a, b) -> grid[a[0]][a[1]] - grid[b[0]][b[1]]
#
# Error in parsing solutions/number-of-islands_2.java
# classcomponent中有未知类型class_declaration class UnionFind {
#     int count; // # of connected components
#     int[] parent;
#     int[] rank;
#
#     public UnionFind(char[][] grid) { // for problem 200
#       count = 0;
#       int m = grid.length;
#       int n = grid[0].length;
#       parent = new int[m * n];
#       rank = new int[m * n];
#       for (int i = 0; i < m; ++i) {
#         for (int j = 0; j < n; ++j) {
#           if (grid[i][j] == '1') {
#             parent[i * n + j] = i * n + j;
#             ++count;
#           }
#           rank[i * n + j] = 0;
#         }
#       }
#     }
#
#     public int find(int i) { // path compression
#       if (parent[i] != i) parent[i] = find(parent[i]);
#       return parent[i];
#     }
#
#     public void union(int x, int y) { // union with rank
#       int rootx = find(x);
#       int rooty = find(y);
#       if (rootx != rooty) {
#         if (rank[rootx] > rank[rooty]) {
#           parent[rooty] = rootx;
#         } else if (rank[rootx] < rank[rooty]) {
#           parent[rootx] = rooty;
#         } else {
#           parent[rooty] = rootx; rank[rootx] += 1;
#         }
#         --count;
#       }
#     }
#
#     public int getCount() {
#       return count;
#     }
#   }
#
# Error in parsing solutions/number-of-nodes-in-the-sub-tree-with-the-same-label_0.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/number-of-nodes-in-the-sub-tree-with-the-same-label_1.java
# expression中有未知类型:lambda_expression value -> new HashSet<Integer>()
#
# Error in parsing solutions/number-of-operations-to-make-network-connected_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<Integer>()
#
# Error in parsing solutions/number-of-operations-to-make-network-connected_1.java
# expression中有未知类型:lambda_expression k -> new ArrayList<Integer>()
#
# Error in parsing solutions/number-of-ways-of-cutting-a-pizza_1.java
# expression中有未知类型:method_reference int[]::clone
#
# Error in parsing solutions/number-of-ways-to-divide-a-long-corridor_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/number-of-ways-to-divide-a-long-corridor_3.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/number-of-ways-to-divide-a-long-corridor_4.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/numbers-with-same-consecutive-differences_0.java
# expression中有未知类型:lambda_expression i->i
#
# Error in parsing solutions/numbers-with-same-consecutive-differences_1.java
# expression中有未知类型:lambda_expression i->i
#
# Error in parsing solutions/optimal-division_0.java
# classcomponent中有未知类型class_declaration class T {
#         float max_val, min_val;
#         String min_str, max_str;
#     }
#
# Error in parsing solutions/optimal-division_1.java
# classcomponent中有未知类型class_declaration class T {
#         float max_val, min_val;
#         String min_str, max_str;
#     }
#
# Error in parsing solutions/optimize-water-distribution-in-a-village_0.java
# expression中有未知类型:lambda_expression (a, b) -> (a.getKey() - b.getKey())
#
# Error in parsing solutions/optimize-water-distribution-in-a-village_1.java
# expression中有未知类型:lambda_expression (a, b) -> a[2] - b[2]
#
# Error in parsing solutions/pairs-of-songs-with-total-durations-divisible-by-60_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/pairs-of-songs-with-total-durations-divisible-by-60_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/palindrome-pairs_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/palindrome-pairs_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/palindrome-pairs_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/palindrome-partitioning-ii_4.java
# expression中有未知类型:dimensions [][]
#
# Error in parsing solutions/palindrome-partitioning-ii_5.java
# expression中有未知类型:dimensions []
#
# Error in parsing solutions/pascals-triangle-ii_1.java
# classcomponent中有未知类型class_declaration private final class RowCol {
#     private int row, col;
#
#     public RowCol(int row, int col) {
#       this.row = row;
#       this.col = col;
#     }
#
#     @Override
#     public int hashCode() {
#       int result = (int) (row ^ (row >>> 32));
#       return (result << 5) - result + (int) (col ^ (col >>> 32)); // 31 * result == (result << 5) - result
#     }
#
#     @Override
#     public boolean equals(Object o) {
#       if (this == o) return true;
#       if (o == null) return false;
#       if (this.getClass() != o.getClass()) return false;
#
#       RowCol rowCol = (RowCol) o;
#       return row == rowCol.row && col == rowCol.col;
#     }
#   }
#
# Error in parsing solutions/path-crossing_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/path-with-maximum-minimum-value_3.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(grid[b[0]][b[1]], grid[a[0]][a[1]])
#
# Error in parsing solutions/path-with-maximum-minimum-value_4.java
# expression中有未知类型:lambda_expression (gridA, gridB) -> {
#             return grid[gridB[0]][gridB[1]] - grid[gridA[0]][gridA[1]];
#         }
#
# Error in parsing solutions/path-with-maximum-probability_1.java
# could not convert string to float: '1d'
#
# Error in parsing solutions/path-with-maximum-probability_2.java
# could not convert string to float: '0d'
#
# Error in parsing solutions/path-with-minimum-effort_1.java
# expression中有未知类型:lambda_expression (a, b) -> (a.difference.compareTo(b.difference))
#
# Error in parsing solutions/path-with-minimum-effort_2.java
# expression中有未知类型:lambda_expression (e1, e2) -> e1.difference - e2.difference
#
# Error in parsing solutions/permutations-ii_0.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/possible-bipartition_0.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/possible-bipartition_1.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/possible-bipartition_2.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/prefix-and-suffix-search_2.java
# primaryexpression中有未知类型:parenthesized_expression (suffix + '{' + prefix)
#
# Error in parsing solutions/prime-palindrome_0.java
# statement中有未知类型throw_statement throw null;
#
# Error in parsing solutions/pseudo-palindromic-paths-in-a-binary-tree_3.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/race-car_0.java
# expression中有未知类型:lambda_expression (a, b) -> a.steps - b.steps
#
# Error in parsing solutions/range-sum-query-2d-mutable_9.java
# arraycreationexpression中有未知类型dimensions []
#
# Error in parsing solutions/reachable-nodes-in-subdivided-graph_0.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a.dist, b.dist)
#
# Error in parsing solutions/reachable-nodes-with-restrictions_0.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/reachable-nodes-with-restrictions_1.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/reachable-nodes-with-restrictions_2.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/rearrange-string-k-distance-apart_0.java
# expression中有未知类型:lambda_expression (a, b) -> b.getKey() - a.getKey()
#
# Error in parsing solutions/reconstruct-itinerary_0.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/reconstruct-itinerary_1.java
# expression中有未知类型:lambda_expression (key, value) -> Collections.sort(value)
#
# Error in parsing solutions/rectangle-area-ii_1.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a[0], b[0])
#
# Error in parsing solutions/rectangle-area-ii_2.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a[0], b[0])
#
# Error in parsing solutions/rectangle-overlap_0.java
# binaryexpression子节点数量不对
#
# Error in parsing solutions/rectangle-overlap_1.java
# binaryexpression子节点数量不对
#
# Error in parsing solutions/redundant-connection_0.java
# statement中有未知类型throw_statement throw new AssertionError();
#
# Error in parsing solutions/redundant-connection_1.java
# statement中有未知类型throw_statement throw new AssertionError();
#
# Error in parsing solutions/regular-expression-matching_1.java
# program中有未知类型enum_declaration enum Result {
#     TRUE, FALSE
# }
#
# Error in parsing solutions/remove-max-number-of-edges-to-keep-graph-fully-traversable_0.java
# classcomponent中有未知类型class_declaration private class UnionFind {
#         int[] representative;
#         int[] componentSize;
#         // Number of distinct components in the graph.
#         int components;
#
#         // Initialize the list representative and componentSize
#         // Each node is representative of itself with size 1.
#         public UnionFind(int n) {
#             components = n;
#             representative = new int[n + 1];
#             componentSize = new int[n + 1];
#
#             for (int i = 0; i <= n; i++) {
#                 representative[i] = i;
#                 componentSize[i] = 1;
#             }
#         }
#
#         // Get the root of a node.
#         int findRepresentative(int x) {
#             if (representative[x] == x) {
#                 return x;
#             }
#
#             // Path compression.
#             return representative[x] = findRepresentative(representative[x]);
#         }
#
#         // Perform the union of two components that belongs to node x and node y.
#         int performUnion(int x, int y) {
#             x = findRepresentative(x); y = findRepresentative(y);
#
#             if (x == y) {
#                 return 0;
#             }
#
#             if (componentSize[x] > componentSize[y]) {
#                 componentSize[x] += componentSize[y];
#                 representative[y] = x;
#             } else {
#                 componentSize[y] += componentSize[x];
#                 representative[x] = y;
#             }
#
#             components--;
#             return 1;
#         }
#
#         // Returns true if all nodes get merged to one.
#         boolean isConnected() {
#             return components == 1;
#         }
#     }
#
# Error in parsing solutions/remove-stones-to-minimize-the-total_0.java
# expression中有未知类型:lambda_expression (a, b) -> b - a
#
# Error in parsing solutions/reorder-routes-to-make-all-paths-lead-to-the-city-zero_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<List<Integer>>()
#
# Error in parsing solutions/reorder-routes-to-make-all-paths-lead-to-the-city-zero_1.java
# expression中有未知类型:lambda_expression k -> new ArrayList<List<Integer>>()
#
# Error in parsing solutions/restore-the-array-from-adjacent-pairs_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/restore-the-array-from-adjacent-pairs_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/roman-to-integer_0.java
# classcomponent中有未知类型static_initializer static {
#         values.put("M", 1000);
#         values.put("D", 500);
#         values.put("C", 100);
#         values.put("L", 50);
#         values.put("X", 10);
#         values.put("V", 5);
#         values.put("I", 1);
#     }
#
# Error in parsing solutions/roman-to-integer_1.java
# classcomponent中有未知类型static_initializer static {
#         values.put("I", 1);
#         values.put("V", 5);
#         values.put("X", 10);
#         values.put("L", 50);
#         values.put("C", 100);
#         values.put("D", 500);
#         values.put("M", 1000);
#         values.put("IV", 4);
#         values.put("IX", 9);
#         values.put("XL", 40);
#         values.put("XC", 90);
#         values.put("CD", 400);
#         values.put("CM", 900);
#     }
#
# Error in parsing solutions/roman-to-integer_2.java
# classcomponent中有未知类型static_initializer static {
#         values.put("M", 1000);
#         values.put("D", 500);
#         values.put("C", 100);
#         values.put("L", 50);
#         values.put("X", 10);
#         values.put("V", 5);
#         values.put("I", 1);
#     }
#
# Error in parsing solutions/rotate-string_0.java
# statement中有未知类型labeled_statement search:
#             for (int s = 0; s < A.length(); ++s) {
#                 for (int i = 0; i < A.length(); ++i) {
#                     if (A.charAt((s+i) % A.length()) != B.charAt(i))
#                         continue search;
#                 }
#                 return true;
#             }
#
# Error in parsing solutions/rotate-string_1.java
# primaryexpression中有未知类型:parenthesized_expression (A + A)
#
# Error in parsing solutions/rotate-string_2.java
# primaryexpression中有未知类型:parenthesized_expression (A.substring(i+1) + A.substring(0, i+1))
#
# Error in parsing solutions/rotate-string_3.java
# primaryexpression中有未知类型:parenthesized_expression (A+A)
#
# Error in parsing solutions/rotting-oranges_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/search-suggestions-system_1.java
# classcomponent中有未知类型class_declaration class Node {
#         boolean isWord = false;
#         List<Node> children = Arrays.asList(new Node[26]);
#     }
#
# Error in parsing solutions/second-minimum-time-to-reach-destination_0.java
# expression中有未知类型:lambda_expression (a, b) -> (a[1] - b[1])
#
# Error in parsing solutions/second-minimum-time-to-reach-destination_1.java
# expression中有未知类型:lambda_expression value -> new ArrayList<Integer>()
#
# Error in parsing solutions/sentence-similarity-ii_0.java
# expression中有未知类型:lambda_expression value -> new HashSet<String>()
#
# Error in parsing solutions/sentence-similarity-ii_1.java
# expression中有未知类型:lambda_expression value -> new HashSet<String>()
#
# Error in parsing solutions/sentence-similarity-ii_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/sentence-similarity_0.java
# expression中有未知类型:lambda_expression value->new HashSet<String>()
#
# Error in parsing solutions/set-mismatch_2.java
# arrayinitializer中有未知类型ternary_expression nums[nums.length - 1] != nums.length ? nums.length : missing
#
# Error in parsing solutions/shortest-bridge_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/shortest-path-in-a-grid-with-obstacles-elimination_0.java
# expression中有未知类型:instanceof_expression other instanceof StepState
#
# Error in parsing solutions/shortest-path-in-binary-matrix_4.java
# expression中有未知类型:lambda_expression (a,b) -> a.totalEstimate - b.totalEstimate
#
# Error in parsing solutions/shortest-path-to-get-all-keys_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/shortest-path-visiting-all-nodes_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/shortest-path-with-alternating-colors_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<List<Integer>>()
#
# Error in parsing solutions/shortest-word-distance-iii_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/similar-string-groups_0.java
# expression中有未知类型:lambda_expression k -> new ArrayList<Integer>()
#
# Error in parsing solutions/similar-string-groups_1.java
# expression中有未知类型:lambda_expression k -> new ArrayList<Integer>()
#
# Error in parsing solutions/single-number-ii_1.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/single-number-iii_0.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/single-threaded-cpu_0.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a[0], b[0])
#
# Error in parsing solutions/sliding-puzzle_0.java
# statement中有未知类型labeled_statement search:
#             for (sr = 0; sr < R; sr++)
#                 for (sc = 0; sc < C; sc++)
#                     if (board[sr][sc] == 0)
#                         break search;
#
# Error in parsing solutions/sliding-puzzle_1.java
# expression中有未知类型:lambda_expression (a, b) ->
#             (a.heuristic + a.depth) - (b.heuristic + b.depth)
#
# Error in parsing solutions/sliding-window-maximum_0.java
# expression中有未知类型:lambda_expression i->i
#
# Error in parsing solutions/slowest-key_0.java
# enhancedforstatement中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/smallest-range-covering-elements-from-k-lists_3.java
# expression中有未知类型:lambda_expression (i, j) -> nums.get(i).get(next[i]) - nums.get(j).get(next[j])
#
# Error in parsing solutions/snakes-and-ladders_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/sort-array-by-parity_0.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a%2, b%2)
#
# Error in parsing solutions/sort-characters-by-frequency_0.java
# expression中有未知类型:lambda_expression (a, b) -> b.length() - a.length()
#
# Error in parsing solutions/sort-characters-by-frequency_1.java
# expression中有未知类型:lambda_expression (a, b) -> counts.get(b) - counts.get(a)
#
# Error in parsing solutions/sort-items-by-groups-respecting-dependencies_0.java
# expression中有未知类型:method_reference Integer::intValue
#
# Error in parsing solutions/soup-servings_1.java
# expression中有未知类型:lambda_expression k -> new HashMap<>()
#
# Error in parsing solutions/sparse-matrix-multiplication_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/sparse-matrix-multiplication_2.java
# classcomponent中有未知类型class_declaration class SparseMatrix {
#         public int cols = 0, rows = 0;
#         public ArrayList<Integer> values = new ArrayList<>();
#         public ArrayList<Integer> colIndex = new ArrayList<>();
#         public ArrayList<Integer> rowIndex = new ArrayList<>();
#
#         // Compressed Sparse Row
#         public SparseMatrix(int[][] matrix) {
#             rows = matrix.length;
#             cols = matrix[0].length;
#             rowIndex.add(0);
#
#             for (int row = 0; row < rows; ++row) {
#                 for (int col = 0; col < cols; ++col) {
#                     if (matrix[row][col] != 0) {
#                         values.add(matrix[row][col]);
#                         colIndex.add(col);
#                     }
#                 }
#                 rowIndex.add(values.size());
#             }
#         }
#
#         // Compressed Sparse Column
#         public SparseMatrix(int[][] matrix, boolean colWise) {
#             rows = matrix.length;
#             cols = matrix[0].length;
#             colIndex.add(0);
#
#             for (int col = 0; col < cols; ++col) {
#                 for (int row = 0; row < rows; ++row) {
#                     if (matrix[row][col] != 0) {
#                         values.add(matrix[row][col]);
#                         rowIndex.add(row);
#                     }
#                 }
#                 colIndex.add(values.size());
#             }
#         }
#     }
#
# Error in parsing solutions/spiral-matrix-iii_0.java
# statement中有未知类型throw_statement throw null;
#
# Error in parsing solutions/split-array-into-consecutive-subsequences_0.java
# expression中有未知类型:lambda_expression (int[] subsequence1, int[] subsequence2) -> {
#             if (subsequence1[1] == subsequence2[1]) {
#                 return (subsequence1[1] - subsequence1[0]) - (subsequence2[1] - subsequence2[0]);
#             }
#             return (subsequence1[1] - subsequence2[1]);
#         }
#
# Error in parsing solutions/split-array-into-fibonacci-sequence_0.java
# statement中有未知类型labeled_statement search: for (int j = i+1; j < Math.min(i+10, N); ++j) {
#                 if (S.charAt(i+1) == '0' && j > i+1) break;
#                 long b = Long.valueOf(S.substring(i+1, j+1));
#                 if (b >= Integer.MAX_VALUE) break;
#
#                 List<Integer> fib = new ArrayList();
#                 fib.add((int) a);
#                 fib.add((int) b);
#
#                 int k = j + 1;
#                 while (k < N) {
#                     long nxt = fib.get(fib.size() - 2) + fib.get(fib.size() - 1);
#                     String nxtS = String.valueOf(nxt);
#
#                     if (nxt <= Integer.MAX_VALUE && S.substring(k).startsWith(nxtS)) {
#                         k += nxtS.length();
#                         fib.add((int) nxt);
#                     }
#                     else continue search;
#                 }
#                 if (fib.size() >= 3) return fib;
#             }
#
# Error in parsing solutions/stock-price-fluctuation_1.java
# expression中有未知类型:lambda_expression (a, b) -> b[0] - a[0]
#
# Error in parsing solutions/string-to-integer-atoi_1.java
# program中有未知类型enum_declaration enum State { q0, q1, q2, qd }
#
# Error in parsing solutions/strobogrammatic-number-ii_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/strobogrammatic-number_2.java
# arrayinitializer中有未知类型ERROR '', '', '', '', '9', '', '8', '6'};
#
#         StringBuilder
#
# Error in parsing solutions/successful-pairs-of-spells-and-potions_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/successful-pairs-of-spells-and-potions_1.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a[0], b[0])
#
# Error in parsing solutions/sum-of-root-to-leaf-binary-numbers_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/sum-root-to-leaf-numbers_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/surrounded-regions_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/surrounded-regions_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/swim-in-rising-water_0.java
# statement中有未知类型throw_statement throw null;
#
# Error in parsing solutions/tallest-billboard_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/tallest-billboard_1.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/the-k-weakest-rows-in-a-matrix_0.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             if (a[0] == b[0]) return a[1] - b[1];
#             else return a[0] - b[0];
#         }
#
# Error in parsing solutions/the-k-weakest-rows-in-a-matrix_4.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             if (a[0] == b[0]) return b[1] - a[1];
#             else return b[0] - a[0];
#         }
#
# Error in parsing solutions/the-kth-factor-of-n_1.java
# expression中有未知类型:lambda_expression (o1, o2) -> o2 - o1
#
# Error in parsing solutions/the-maze-ii_3.java
# expression中有未知类型:lambda_expression (a, b) -> a[2] - b[2]
#
# Error in parsing solutions/the-maze-iii_0.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             int distA = a.dist;
#             int distB = b.dist;
#
#             if (distA == distB) {
#                 return a.path.compareTo(b.path);
#             }
#
#             return distA - distB;
#         }
#
# Error in parsing solutions/the-number-of-weak-characters-in-the-game_0.java
# expression中有未知类型:lambda_expression (a, b) -> (a[0] == b[0]) ? (b[1] - a[1]) : a[0] - b[0]
#
# Error in parsing solutions/the-skyline-problem_2.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             return b.get(0) - a.get(0);
#         }
#
# Error in parsing solutions/the-skyline-problem_3.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             return b - a;
#         }
#
# Error in parsing solutions/third-maximum-number_4.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/time-based-key-value-store_2.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/time-needed-to-inform-all-employees_1.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/top-k-frequent-elements_0.java
# expression中有未知类型:lambda_expression (n1, n2) -> count.get(n1) - count.get(n2)
#
# Error in parsing solutions/top-k-frequent-words_0.java
# expression中有未知类型:lambda_expression (w1, w2) -> cnt.get(w1).equals(cnt.get(w2)) ? w1.compareTo(w2) : cnt.get(w2) - cnt.get(w1)
#
# Error in parsing solutions/top-k-frequent-words_2.java
# expression中有未知类型:lambda_expression (w1, w2) -> cnt.get(w1).equals(cnt.get(w2)) ? w2.compareTo(w1) : cnt.get(w1) - cnt.get(w2)
#
# Error in parsing solutions/total-cost-to-hire-k-workers_1.java
# expression中有未知类型:lambda_expression (a, b) -> {
#             if (a[0] == b[0]) {
#                 return a[1] - b[1];
#             }
#             return a[0] - b[0];}
#
# Error in parsing solutions/two-sum-iii-data-structure-design_1.java
# generic_type中有未知类型scoped_type_identifier Map.Entry
#
# Error in parsing solutions/unique-binary-search-trees-ii_0.java
# classdeclaration中有未知类型:identifier
#
# Error in parsing solutions/valid-palindrome_0.java
# expression中有未知类型:lambda_expression c -> Character.isLetterOrDigit(c)
#
# Error in parsing solutions/valid-square_1.java
# expression中有未知类型:lambda_expression (l1, l2) -> l2[0] == l1[0] ? l1[1] - l2[1] : l1[0] - l2[0]
#
# Error in parsing solutions/validate-ip-address_0.java
# statement中有未知类型try_statement try {
#       return (InetAddress.getByName(IP) instanceof Inet6Address) ? "IPv6": "IPv4";
#     } catch(Exception e) {}
#
# Error in parsing solutions/widest-vertical-area-between-two-points-containing-no-points_0.java
# expression中有未知类型:lambda_expression (a, b) -> Integer.compare(a[0], b[0])
#
# Error in parsing solutions/wildcard-matching_0.java
# expression中有未知类型:lambda_expression c -> c == '*'
#
# Error in parsing solutions/word-abbreviation_1.java
# expression中有未知类型:lambda_expression (a, b) -> a.word.compareTo(b.word)
#
# Error in parsing solutions/word-ladder_0.java
# expression中有未知类型:lambda_expression word -> {
#             for (int i = 0; i < L; i++) {
#                 // Key is the generic word
#                 // Value is a list of words which have the same intermediate generic word.
#                 String newWord = word.substring(0, i) + '*' + word.substring(i + 1, L);
#                 List<String> transformations = allComboDict.getOrDefault(newWord, new ArrayList<>());
#                 transformations.add(word);
#                 allComboDict.put(newWord, transformations);
#             }
#         }
#
# Error in parsing solutions/word-ladder_1.java
# expression中有未知类型:lambda_expression word -> {
#             for (int i = 0; i < L; i++) {
#                 // Key is the generic word
#                 // Value is a list of words which have the same intermediate generic word.
#                 String newWord = word.substring(0, i) + '*' + word.substring(i + 1, L);
#                 List<String> transformations =
#                         this.allComboDict.getOrDefault(newWord, new ArrayList<>());
#                 transformations.add(word);
#                 this.allComboDict.put(newWord, transformations);
#             }
#         }
#
# Error in parsing solutions/word-subsets_0.java
# statement中有未知类型labeled_statement search: for (String a: A) {
#             int[] aCount = count(a);
#             for (int i = 0; i < 26; ++i)
#                 if (aCount[i] < bmax[i])
#                     continue search;
#             ans.add(a);
#         }
#
# Error in parsing solutions/x-of-a-kind-in-a-deck-of-cards_0.java
# statement中有未知类型labeled_statement search: for (int X = 2; X <= N; ++X)
#             if (N % X == 0) {
#                 for (int v: values)
#                     if (v % X != 0)
#                         continue search;
#                 return true;
#             }
#
# Error in parsing solutions/zigzag-iterator_1.java
# classdeclaration中有未知类型:identifier
# Total errors: 327 out of 2409 files.

# %% [markdown]
# ## Translating Program Model into Coq Proof

# %%
# coq proof test
def validateCoqProof(file_path):
    program=getProgram(file_path)
    coqProof=program.toCoq().toString()
    prefix="""From PLF Require Import Syntax.
Open Scope string_scope.

Example prog_well_typed : exists p, program_well_typed p.
Proof with (simpl;try(reflexivity)).
unfold program_well_typed.
eexists.
eexists."""
    suffix="""Defined.
Definition prog := the_exists_term (prog_well_typed).
Print prog."""
    coqProof=f"{prefix}\n{coqProof}\n{suffix}"
    with open("../demo/test.v", "w") as file:
        file.write(coqProof)

validateCoqProof("test.java")
